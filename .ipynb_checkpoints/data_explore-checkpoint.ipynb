# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data\\NBA_Player_Dataset-2013-2021_3-12-22.csv')

# %%
plt.figure(figsize=(20, 20))
# define the mask to set the values in the upper triangle to True
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
heatmap = sns.heatmap(df.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap = "vlag", annot_kws={"fontsize":8})
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=16)

plt.tight_layout()
plt.savefig('images/correlation_heatmap.png')
plt.show()

# %%
sns.lmplot(x='Salary',y='PPG',data=df)

# %%
sns.lmplot(x='Salary',y='MPG',data=df)

# %%
sns.lmplot(x='Salary',y='APG',data=df)
